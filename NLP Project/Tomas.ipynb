# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import re
import spacy

from collections import Counter, defaultdict
from transformers import AutoTokenizer
from sklearn.feature_extraction.text import TfidfVectorizer

from gensim.models import Word2Vec

from sklearn.manifold import TSNE

from tqdm import tqdm

# spacy.cli.download("en_core_web_lg")
nlp = spacy.load('en_core_web_lg')

# %% [markdown]
# ### Basic Preprocessing

# %%
def read_csv(filename):

    return pd.read_csv(filename, sep=',', encoding='utf-8', index_col=0).iloc[:, -2:].reset_index(drop=True)


def preprocess(text):

    # remove URLs
    text = re.sub('http\S*', ' ', text)

    # remove non-alphabetic
    text = re.sub("[^a-zA-Z]", " ", text)

    # make lowercase
    text = text.lower()

    # remove one character word
    text = re.sub("\s+[a-zA-Z]\s+", ' ', text)
    text = re.sub("^[a-zA-Z]\s+", '', text)

    # replace double space to one space
    text = re.sub("\s+", ' ', text)

    # tokenize, lemmatize, remove stop words
    doc = nlp(text)
    text = [token.lemma_ for token in doc if not token.is_stop]
    return " ".join(text)

# %%
tweets_train = read_csv('train.csv')

tweets_train['clean_text'] = tweets_train['text'].apply(preprocess)

# %%
tweets_train.head()
# Out:
#                                                 text  target  \
# 0  Our Deeds are the Reason of this #earthquake M...       1
# 1             Forest fire near La Ronge Sask. Canada       1
# 2  All residents asked to 'shelter in place' are ...       1
# 3  13,000 people receive #wildfires evacuation or...       1
# 4  Just got sent this photo from Ruby #Alaska as ...       1
#
#                                           clean_text
# 0               deed reason earthquake allah forgive
# 1              forest fire near la ronge sask canada
# 2  resident ask shelter place notify officer evac...
# 3    people receive wildfire evacuation order cal...
# 4  get send photo ruby alaska smoke wildfire pour...

# %%
class BPE():
    """Byte-Pair Encoding: Subword-based tokenization algorithm."""

    def __init__(self, corpus, vocab_size):
        """Initialize BPE tokenizer."""
        self.corpus = corpus
        self.vocab_size = vocab_size
        self.tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
        self.word_freqs = defaultdict(int)
        self.splits = {}
        self.merges = {}

    def train(self):
        """Train BPE tokenizer."""
        self._compute_word_frequencies()
        self._compute_base_alphabet()
        self._initialize_vocab()

        while len(self.vocab) < self.vocab_size:
            pair_freqs = self._compute_pair_freqs()
            best_pair = max(pair_freqs, key=pair_freqs.get)
            self._merge_pair(*best_pair)
            self.merges[best_pair] = best_pair[0] + best_pair[1]
            self.vocab.append(best_pair[0] + best_pair[1])

        return self.merges

    def _compute_word_frequencies(self):
        """Compute the frequencies of each word in the corpus."""
        for text in self.corpus:
            words_with_offsets = self.tokenizer.backend_tokenizer.pre_tokenizer.pre_tokenize_str(text)
            new_words = [word for word, offset in words_with_offsets]
            for word in new_words:
                self.word_freqs[word] += 1

    def _compute_base_alphabet(self):
        """Compute the base vocabulary of all characters in the corpus."""
        alphabet = set()
        for word in self.word_freqs.keys():
            alphabet.update(set(word))
        self.alphabet = sorted(list(alphabet))

    def _initialize_vocab(self):
        """Initialize vocabulary with base characters and special token."""
        self.vocab = ["</w>"] + self.alphabet.copy()
        self.splits = {word: [c for c in word] for word in self.word_freqs.keys()}

    def _compute_pair_freqs(self):
        """Compute the frequency of each pair."""
        pair_freqs = defaultdict(int)
        for word, freq in self.word_freqs.items():
            subword_splits = self.splits[word]
            if len(subword_splits) == 1:
                continue
            for i in range(len(subword_splits) - 1):
                pair = (subword_splits[i], subword_splits[i + 1])
                pair_freqs[pair] += freq
        return pair_freqs

    def _merge_pair(self, a, b):
        """Merge the given pair."""
        for word in self.word_freqs:
            subword_splits = self.splits[word]
            if len(subword_splits) == 1:
                continue
            i = 0
            while i < len(subword_splits) - 1:
                if subword_splits[i] == a and subword_splits[i + 1] == b:
                    subword_splits = subword_splits[:i] + [a + b] + subword_splits[i + 2 :]
                else:
                    i += 1
            self.splits[word] = subword_splits

    def tokenize(self, text):
        """Tokenize a given text with trained BPE tokenizer."""
        pre_tokenize_result = self.tokenizer._tokenizer.pre_tokenizer.pre_tokenize_str(text)
        pre_tokenized_text = [word for word, offset in pre_tokenize_result]
        subword_splits_text = [[l for l in word] for word in pre_tokenized_text]

        for pair, merge in self.merges.items():
            for idx, subword_splits in enumerate(subword_splits_text):
                i = 0
                while i < len(subword_splits) - 1:
                    if subword_splits[i] == pair[0] and subword_splits[i + 1] == pair[1]:
                        subword_splits = subword_splits[:i] + [merge] + subword_splits[i + 2 :]
                    else:
                        i += 1
                subword_splits_text[idx] = subword_splits

        result = sum(subword_splits_text, [])
        return result

# %%
# Instantiate BPE with your preprocessed text data and set vocabulary size
bpe_tokenizer = BPE(tweets_train['clean_text'], vocab_size=3000)  # You can adjust the vocab_size

# Train the BPE tokenizer
bpe_tokenizer.train()

# Apply the trained BPE tokenizer to your text
tweets_train['tokenized_text'] = tweets_train['clean_text'].apply(bpe_tokenizer.tokenize)

# Display the original and tokenized text
for idx, row in tweets_train[['clean_text', 'tokenized_text']].iterrows():
    print(f"Original Text: {row['clean_text']}")
    print(f"Tokenized Text: {row['tokenized_text']}")
    print("\n" + "="*50 + "\n")  # Just for better separation in output
# Out:
# Original Text: deed reason earthquake allah forgive
# Tokenized Text: ['de', 'ed', 'reason', 'earthquake', 'allah', 'for', 'give']
#
# ==================================================
#
# Original Text: forest fire near la ronge sask canada
# Tokenized Text: ['forest', 'fire', 'near', 'la', 'ron', 'ge', 's', 'ask', 'canada']
#
# ==================================================
#
# Original Text: resident ask shelter place notify officer evacuation shelter place order expect
# Tokenized Text: ['resident', 'ask', 'shel', 'ter', 'place', 'not', 'ify', 'officer', 'evacuation', 'shel', 'ter', 'place', 'order', 'expect']
#
# ==================================================
#
# Original Text:   people receive wildfire evacuation order california
# Tokenized Text: ['people', 're', 'ce', 'ive', 'wildfire', 'evacuation', 'order', 'california']
#
# ==================================================
#
# Original Text: get send photo ruby alaska smoke wildfire pour school
# Tokenized Text: ['get', 'send', 'photo', 'ru', 'by', 'alaska', 'smoke', 'wildfire', 'po', 'ur', 'school']
#
# ==================================================
#
# Original Text:   rockyfire update california hwy close direction lake county fire cafire wildfire
# Tokenized Text: ['rocky', 'fire', 'update', 'california', 'hwy', 'close', 'direction', 'lake', 'county', 'fire', 'ca', 'fire', 'wildfire']
#
# ==================================================
#
# Original Text:   flood disaster heavy rain cause flash flooding street manitou colorado spring area
# Tokenized Text: ['flood', 'disaster', 'heavy', 'rain', 'cause', 'flash', 'flooding', 'street', 'man', 'it', 'ou', 'colorado', 'spring', 'area']
#
# ==================================================
#
# Original Text: hill fire wood
# Tokenized Text: ['hill', 'fire', 'wood']
#
# ==================================================
#
# Original Text: emergency evacuation happen building street
# Tokenized Text: ['emergency', 'evacuation', 'happen', 'building', 'street']
#
# ==================================================
#
# Original Text: afraid tornado come area
# Tokenized Text: ['af', 'raid', 'tornado', 'come', 'area']
#
# ==================================================
#
# Original Text: people die heat wave far
# Tokenized Text: ['people', 'die', 'heat', 'wave', 'far']
#
# ==================================================
#
# Original Text: haha south tampa getting flood hah wait second live south tampa go to go to fvck flooding
# Tokenized Text: ['haha', 'south', 't', 'amp', 'a', 'getting', 'flood', 'ha', 'h', 'wait', 'second', 'live', 'south', 't', 'amp', 'a', 'go', 'to', 'go', 'to', 'f', 'v', 'ck', 'flooding']
#
# ==================================================
#
# Original Text:   rain flooding florida tampabay tampa day ve lose count
# Tokenized Text: ['rain', 'flooding', 'florida', 't', 'amp', 'ab', 'ay', 't', 'amp', 'a', 'day', 've', 'lose', 'count']
#
# ==================================================
#
# Original Text:   flood bago myanmar arrive bago
# Tokenized Text: ['flood', 'ba', 'go', 'myanmar', 'arrive', 'ba', 'go']
#
# ==================================================
#
# Original Text: damage school bus multi car crash breaking
# Tokenized Text: ['damage', 'school', 'bus', 'multi', 'car', 'crash', 'breaking']
#
# ==================================================
#
# Original Text: man
# Tokenized Text: ['man']
#
# ==================================================
#
# Original Text: love fruit
# Tokenized Text: ['love', 'fru', 'it']
#
# ==================================================
#
# Original Text: summer lovely
# Tokenized Text: ['summer', 'lovely']
#
# ==================================================
#
# Original Text: car fast
# Tokenized Text: ['car', 'fast']
#
# ==================================================
#
# Original Text: goooooooaaaaaal
# Tokenized Text: ['go', 'oooooo', 'aaaa', 'a', 'al']
#
# ==================================================
#
# Original Text: ridiculous
# Tokenized Text: ['rid', 'ic', 'u', 'lo', 'us']
#
# ==================================================
#
# Original Text: london cool
# Tokenized Text: ['london', 'cool']
#
# ==================================================
#
# Original Text: love skiing
# Tokenized Text: ['love', 'sk', 'i', 'ing']
#
# ==================================================
#
# Original Text: wonderful day
# Tokenized Text: ['wonder', 'ful', 'day']
#
# ==================================================
#
# Original Text: looooool
# Tokenized Text: ['lo', 'oooo', 'ol']
#
# ==================================================
#
# Original Text: way eat shit
# Tokenized Text: ['way', 'eat', 'shit']
#
# ==================================================
#
# Original Text: nyc week
# Tokenized Text: ['nyc', 'week']
#
# ==================================================
#
# Original Text: love girlfriend
# Tokenized Text: ['love', 'girl', 'friend']
#
# ==================================================
#
# Original Text: cooool
# Tokenized Text: ['co', 'oo', 'ol']
#
# ==================================================
#
# Original Text: like pasta
# Tokenized Text: ['like', 'past', 'a']
#
# ==================================================
#
# Original Text: end
# Tokenized Text: ['end']
#
# ==================================================
#
# Original Text:   bbcmtd wholesale market ablaze
# Tokenized Text: ['bbc', 'mt', 'd', 'w', 'hole', 'sale', 'market', 'ablaze']
#
# ==================================================
#
# Original Text: try bring heavy metal rt
# Tokenized Text: ['try', 'bring', 'heavy', 'metal', 'rt']
#
# ==================================================
#
# Original Text:   africanbaze break news nigeria flag set ablaze aba
# Tokenized Text: ['afric', 'an', 'ba', 'ze', 'break', 'news', 'niger', 'ia', 'flag', 'set', 'ablaze', 'aba']
#
# ==================================================
#
# Original Text: cry set ablaze
# Tokenized Text: ['cry', 'set', 'ablaze']
#
# ==================================================
#
# Original Text: plus look sky night ablaze
# Tokenized Text: ['plus', 'look', 'sky', 'night', 'ablaze']
#
# ==================================================
#
# Original Text:   phdsquares mufc ve build hype new acquisition doubt set epl ablaze season
# Tokenized Text: ['ph', 'd', 'squ', 'are', 's', 'mu', 'fc', 've', 'build', 'hy', 'pe', 'new', 'ac', 'qu', 'is', 'ition', 'do', 'ub', 't', 'set', 'e', 'pl', 'ablaze', 'season']
#
# ==================================================
#
# Original Text: inec office abia set ablaze
# Tokenized Text: ['ine', 'c', 'office', 'ab', 'ia', 'set', 'ablaze']
#
# ==================================================
#
# Original Text: barbados bridgetown jamaica car set ablaze santa cruz head st elizabeth police superintende
# Tokenized Text: ['bar', 'bad', 'os', 'b', 'rid', 'get', 'own', 'jama', 'ica', 'car', 'set', 'ablaze', 's', 'anta', 'cruz', 'head', 'st', 'eli', 'za', 'be', 'th', 'police', 'super', 'inten', 'de']
#
# ==================================================
#
# Original Text: ablaze lord d
# Tokenized Text: ['ablaze', 'lord', 'd']
#
# ==================================================
#
# Original Text: check nsfw
# Tokenized Text: ['check', 'n', 'sf', 'w']
#
# ==================================================
#
# Original Text: outside ablaze alive dead inside
# Tokenized Text: ['outside', 'ablaze', 'alive', 'dead', 'inside']
#
# ==================================================
#
# Original Text: awesome time visit cfc head office ancop site ablaze thank tita vida take care
# Tokenized Text: ['awesome', 'time', 'visit', 'c', 'fc', 'head', 'office', 'an', 'cop', 'site', 'ablaze', 'thank', 'tit', 'a', 'vi', 'da', 'take', 'care']
#
# ==================================================
#
# Original Text: soooo pump ablaze southridgelife
# Tokenized Text: ['so', 'oo', 'o', 'pump', 'ablaze', 'south', 'ridge', 'life']
#
# ==================================================
#
# Original Text: want set chicago ablaze preaching hotel
# Tokenized Text: ['want', 'set', 'chicago', 'ablaze', 'pre', 'ach', 'ing', 'hot', 'el']
#
# ==================================================
#
# Original Text: gain follower week know stat grow
# Tokenized Text: ['gain', 'follower', 'week', 'know', 'stat', 'grow']
#
# ==================================================
#
# Original Text: west burn thousand wildfire ablaze california
# Tokenized Text: ['west', 'burn', 'thousand', 'wildfire', 'ablaze', 'california']
#
# ==================================================
#
# Original Text: build perfect tracklist life leave street ablaze
# Tokenized Text: ['build', 'perfect', 'track', 'list', 'life', 'leave', 'street', 'ablaze']
#
# ==================================================
#
# Original Text: check nsfw
# Tokenized Text: ['check', 'n', 'sf', 'w']
#
# ==================================================
#
# Original Text: night retainer weird well wear single night year
# Tokenized Text: ['night', 're', 'tain', 'er', 'weird', 'well', 'wear', 'single', 'night', 'year']
#
# ==================================================
#
# Original Text: deputy man shoot brighton home set ablaze
# Tokenized Text: ['dep', 'ut', 'y', 'man', 'shoot', 'b', 'right', 'on', 'home', 'set', 'ablaze']
#
# ==================================================
#
# Original Text: man wife year jail set ablaze niece
# Tokenized Text: ['man', 'wife', 'year', 'j', 'ail', 'set', 'ablaze', 'nie', 'ce']
#
# ==================================================
#
# Original Text: santa cruz head st elizabeth police superintendent lanford salmon
# Tokenized Text: ['s', 'anta', 'cruz', 'head', 'st', 'eli', 'za', 'be', 'th', 'police', 'super', 'int', 'end', 'ent', 'lan', 'ford', 'sal', 'mon']
#
# ==================================================
#
# Original Text: police arsonist deliberately set black church north carolina ablaze
# Tokenized Text: ['police', 'arsonist', 'de', 'liber', 'ately', 'set', 'black', 'church', 'north', 'car', 'ol', 'ina', 'ablaze']
#
# ==================================================
#
# Original Text: noche el bestia alexis sanchez happy teammate train hard goodnight gunner
# Tokenized Text: ['no', 'che', 'el', 'best', 'ia', 'alex', 'is', 'san', 'che', 'z', 'happy', 'team', 'mate', 'train', 'hard', 'good', 'night', 'gun', 'ner']
#
# ==================================================
#
# Original Text:   kurd trample turkmen flag later set ablaze vandalize office turkmen diyala
# Tokenized Text: ['kur', 'd', 'tr', 'ample', 'tur', 'km', 'en', 'flag', 'later', 'set', 'ablaze', 'v', 'and', 'al', 'ize', 'office', 'tur', 'km', 'en', 'di', 'y', 'al', 'a']
#
# ==================================================
#
# Original Text: truck ablaze voortrekker ave outside tambo intl cargo section
# Tokenized Text: ['truck', 'ablaze', 'vo', 'ort', 're', 'k', 'ker', 'ave', 'outside', 't', 'am', 'bo', 'int', 'l', 'car', 'go', 'se', 'ction']
#
# ==================================================
#
# Original Text: set heart ablaze city gift skyline like kiss lip
# Tokenized Text: ['set', 'heart', 'ablaze', 'city', 'gi', 'ft', 'sky', 'line', 'like', 'kis', 's', 'lip']
#
# ==================================================
#
# Original Text: sky ablaze tonight los angeles m expect ig fb fill sunset shot know peep
# Tokenized Text: ['sky', 'ablaze', 'tonight', 'los', 'ange', 'les', 'm', 'expect', 'ig', 'f', 'b', 'fill', 'sun', 'set', 'shot', 'know', 'pe', 'ep']
#
# ==================================================
#
# Original Text: west burn thousand wildfire ablaze california climate energy
# Tokenized Text: ['west', 'burn', 'thousand', 'wildfire', 'ablaze', 'california', 'climate', 'en', 'ergy']
#
# ==================================================
#
# Original Text: revel wmv video mean mac farewell ablaze wmv en route dvd gtxrwm
# Tokenized Text: ['re', 'vel', 'w', 'm', 'v', 'video', 'mean', 'mac', 'f', 'are', 'well', 'ablaze', 'w', 'm', 'v', 'en', 'route', 'd', 'vd', 'gt', 'x', 'r', 'w', 'm']
#
# ==================================================
#
# Original Text: progressive greeting month student set pen ablaze torch publication
# Tokenized Text: ['progress', 'ive', 'gre', 'et', 'ing', 'month', 'student', 'set', 'pen', 'ablaze', 'tor', 'ch', 'public', 'ation']
#
# ==================================================
#
# Original Text: rene ablaze amp jacinta secret fall sky edit mar
# Tokenized Text: ['re', 'ne', 'ablaze', 'amp', 'jac', 'in', 'ta', 'secret', 'fall', 'sky', 'ed', 'it', 'mar']
#
# ==================================================
#
# Original Text:   navista steve fire california tinderbox clown set hood ablaze news
# Tokenized Text: ['na', 'vi', 'st', 'a', 'steve', 'fire', 'california', 'tin', 'der', 'box', 'c', 'lown', 'set', 'hood', 'ablaze', 'news']
#
# ==================================================
#
# Original Text:   nowplaye rene ablaze amp ian buff magnitude edm
# Tokenized Text: ['nowplaye', 're', 'ne', 'ablaze', 'amp', 'ian', 'buff', 'magn', 'it', 'ude', 'edm']
#
# ==================================================
#
# Original Text:   nxwestmidland huge fire wholesale market ablaze
# Tokenized Text: ['n', 'x', 'west', 'mid', 'land', 'huge', 'fire', 'w', 'hole', 'sale', 'market', 'ablaze']
#
# ==================================================
#
# Original Text:   ablaze time talk don know work
# Tokenized Text: ['ablaze', 'time', 'talk', 'don', 'know', 'work']
#
# ==================================================
#
# Original Text:   kid cuz get bicycle accident amp split testicle impossible kid michael father
# Tokenized Text: ['kid', 'cu', 'z', 'get', 'bicy', 'cle', 'accident', 'amp', 'sp', 'lit', 'test', 'icle', 'im', 'possible', 'kid', 'michael', 'father']
#
# ==================================================
#
# Original Text: accident w nashvilletraffic traffic move slow usual
# Tokenized Text: ['accident', 'w', 'nashville', 'traffic', 'traffic', 'move', 'slow', 'u', 'sual']
#
# ==================================================
#
# Original Text: accident center lane block santaclara nb great america pkwy bayarea traffic
# Tokenized Text: ['accident', 'center', 'lane', 'block', 's', 'ant', 'ac', 'lar', 'a', 'n', 'b', 'great', 'america', 'p', 'k', 'wy', 'bay', 'area', 'traffic']
#
# ==================================================
#
# Original Text:   personalinjury accident summer read advice amp solicitor help otleyhour
# Tokenized Text: ['person', 'al', 'injury', 'accident', 'summer', 'read', 'adv', 'ice', 'amp', 'so', 'lic', 'itor', 'help', 'ot', 'ley', 'hour']
#
# ==================================================
#
# Original Text:   stlouis caraccidentlawyer speeding cause teen accident car accident tee
# Tokenized Text: ['st', 'louis', 'car', 'accident', 'la', 'wy', 'er', 'spe', 'ed', 'ing', 'cause', 'teen', 'accident', 'car', 'accident', 'te', 'e']
#
# ==================================================
#
# Original Text: report motor vehicle accident curry herman rd near stephenson involve overturned vehicle use
# Tokenized Text: ['report', 'motor', 'vehicle', 'accident', 'cur', 'ry', 'her', 'man', 'rd', 'near', 'stephen', 'son', 'involve', 'over', 'tur', 'ned', 'vehicle', 'use']
#
# ==================================================
#
# Original Text: bigrigradio live accident awareness
# Tokenized Text: ['big', 'ri', 'gra', 'dio', 'live', 'accident', 'a', 'ware', 'ness']
#
# ==================================================
#
# Original Text: mile marker south mooresville iredell vehicle accident ramp close pm
# Tokenized Text: ['mile', 'mar', 'ker', 'south', 'mo', 'ore', 's', 'ville', 'ire', 'de', 'll', 'vehicle', 'accident', 'r', 'amp', 'close', 'pm']
#
# ==================================================
#
# Original Text: rt sleepjunkies sleep pill double risk car accident
# Tokenized Text: ['rt', 'sleep', 'j', 'unk', 'ies', 'sleep', 'p', 'ill', 'double', 'risk', 'car', 'accident']
#
# ==================================================
#
# Original Text:   accident know gon happen
# Tokenized Text: ['accident', 'know', 'gon', 'happen']
#
# ==================================================
#
# Original Text: traffic accident cabrillo hwy magellan av mir
# Tokenized Text: ['traffic', 'accident', 'cab', 'r', 'il', 'lo', 'hwy', 'mage', 'll', 'an', 'av', 'mir']
#
# ==================================================
#
# Original Text: mile marker south mooresville iredell vehicle accident congestion pm
# Tokenized Text: ['mile', 'mar', 'ker', 'south', 'mo', 'ore', 's', 'ville', 'ire', 'de', 'll', 'vehicle', 'accident', 'con', 'ge', 'st', 'ion', 'pm']
#
# ==================================================
#
# Original Text: pastor scene accident owner range rover
# Tokenized Text: ['past', 'or', 'scene', 'accident', 'owner', 'r', 'ange', 'ro', 'ver']
#
# ==================================================
#
# Original Text: mom didn home fast wish mom accident truck spilt mayonnaise
# Tokenized Text: ['mom', 'didn', 'home', 'fast', 'wish', 'mom', 'accident', 'truck', 'sp', 'il', 't', 'may', 'on', 'na', 'ise']
#
# ==================================================
#
# Original Text: horrible car accident past sunday m finally able thank god
# Tokenized Text: ['horrible', 'car', 'accident', 'past', 'sunday', 'm', 'finally', 'able', 'thank', 'god']
#
# ==================================================
#
# Original Text: wait pissed donnie tell accident
# Tokenized Text: ['wait', 'p', 'is', 'se', 'd', 'don', 'nie', 'tell', 'accident']
#
# ==================================================
#
# Original Text:   truckcrash overturn fortworth interstate click ve crash gt
# Tokenized Text: ['truck', 'crash', 'over', 'turn', 'fort', 'worth', 'inter', 'state', 'cli', 'ck', 've', 'crash', 'gt']
#
# ==================================================
#
# Original Text: accident ashville sb sr traffic
# Tokenized Text: ['accident', 'ash', 'ville', 'sb', 's', 'r', 'traffic']
#
# ==================================================
#
# Original Text: carolina accident motorcyclist die crash car cross median motorcycle rider travel
# Tokenized Text: ['car', 'ol', 'ina', 'accident', 'motorcyclist', 'die', 'crash', 'car', 'cross', 'medi', 'an', 'motor', 'cycle', 'ri', 'der', 'travel']
#
# ==================================================
#
# Original Text: fyi cad fyi accident property damage nhs piner rd horndale dr
# Tokenized Text: ['fy', 'i', 'c', 'ad', 'fy', 'i', 'accident', 'property', 'damage', 'nh', 's', 'pin', 'er', 'rd', 'hor', 'nd', 'ale', 'dr']
#
# ==================================================
#
# Original Text: rt naayf accident year turn chandanee magu near mma taxi ram halfway turn conf
# Tokenized Text: ['rt', 'na', 'ay', 'f', 'accident', 'year', 'turn', 'ch', 'and', 'ane', 'e', 'ma', 'gu', 'near', 'm', 'ma', 'tax', 'i', 'ram', 'half', 'way', 'turn', 'con', 'f']
#
# ==================================================
#
# Original Text: accident leave lane block manchester rt nb eddy rd stop traffic nh delay min traffic
# Tokenized Text: ['accident', 'leave', 'lane', 'block', 'manchester', 'rt', 'n', 'b', 'ed', 'dy', 'rd', 'stop', 'traffic', 'nh', 'delay', 'min', 'traffic']
#
# ==================================================
#
# Original Text:   accident property damage piner rd horndale dr
# Tokenized Text: ['accident', 'property', 'damage', 'pin', 'er', 'rd', 'hor', 'nd', 'ale', 'dr']
#
# ==================================================
#
# Original Text:   accident
# Tokenized Text: ['accident']
#
# ==================================================
#
# Original Text: fyi cad fyi accident property damage wpd th st
# Tokenized Text: ['fy', 'i', 'c', 'ad', 'fy', 'i', 'accident', 'property', 'damage', 'w', 'pd', 'th', 'st']
#
# ==================================================
#
# Original Text:   pm traffic accident injury willis foreman rd
# Tokenized Text: ['pm', 'traffic', 'accident', 'injury', 'willi', 's', 'fore', 'man', 'rd']
#
# ==================================================
#
# Original Text: aashiqui actress anu aggarwal near fatal accident
# Tokenized Text: ['aa', 'shi', 'qu', 'i', 'act', 'ress', 'an', 'u', 'ag', 'gar', 'wal', 'near', 'fatal', 'accident']
#
# ==================================================
#
# Original Text: suffield alberta accident
# Tokenized Text: ['su', 'f', 'field', 'al', 'ber', 'ta', 'accident']
#
# ==================================================
#
# Original Text:   mile backup south accident block right lane exit langtree rd consider nc nc nc alternate
# Tokenized Text: ['mile', 'back', 'up', 'south', 'accident', 'block', 'right', 'lane', 'exit', 'lan', 'gt', 'ree', 'rd', 'consider', 'nc', 'nc', 'nc', 'al', 'tern', 'ate']
#
# ==================================================
#
# Original Text: accident change life help determine option financially support life care plan go treatment
# Tokenized Text: ['accident', 'change', 'life', 'help', 'de', 'ter', 'mine', 'option', 'fin', 'anci', 'ally', 'support', 'life', 'care', 'plan', 'go', 'treat', 'ment']
#
# ==================================================
#
# Original Text:   break deadly motorcycle car accident happen hagerstown today ll detail state whag
# Tokenized Text: ['break', 'deadly', 'motor', 'cycle', 'car', 'accident', 'happen', 'ha', 'ger', 'st', 'own', 'today', 'll', 'de', 'tail', 'state', 'w', 'ha', 'g']
#
# ==================================================
#
# Original Text:   flowri marinade accident
# Tokenized Text: ['flow', 'ri', 'mar', 'ina', 'de', 'accident']
#
# ==================================================
#
# Original Text: car week get fucking car accident mfs fucking drive
# Tokenized Text: ['car', 'week', 'get', 'fucking', 'car', 'accident', 'm', 'fs', 'fucking', 'drive']
#
# ==================================================
#
# Original Text:   norwaymfa bahrain police previously die road accident kill explosion
# Tokenized Text: ['nor', 'way', 'mfa', 'b', 'ah', 'rain', 'police', 'pre', 'vious', 'ly', 'die', 'road', 'accident', 'kill', 'explosion']
#
# ==================================================
#
# Original Text: hear church leader kenya come forward comment accident issue disciplinary measure arrestpastornganga
# Tokenized Text: ['hear', 'church', 'leader', 'ken', 'ya', 'come', 'for', 'ward', 'comment', 'accident', 'issue', 'dis', 'ci', 'pl', 'in', 'ary', 'me', 'a', 'sure', 'arrest', 'past', 'or', 'n', 'gan', 'ga']
#
# ==================================================
#
# Original Text:   aftershock delo scuf ps live game cya
# Tokenized Text: ['aftershock', 'de', 'lo', 'sc', 'u', 'f', 'ps', 'live', 'game', 'cy', 'a']
#
# ==================================================
#
# Original Text:   man drive effort get painful man win roger bannister
# Tokenized Text: ['man', 'drive', 'effort', 'get', 'pain', 'ful', 'man', 'win', 'ro', 'ger', 'ban', 'ni', 'ster']
#
# ==================================================
#
# Original Text:   ir icemoon aftershock djicemoon dubstep trapmusic dnb edm dance ice
# Tokenized Text: ['ir', 'icemoon', 'aftershock', 'dj', 'icemoon', 'dub', 'step', 'tra', 'pm', 'us', 'ic', 'dnb', 'edm', 'dance', 'ice']
#
# ==================================================
#
# Original Text:   victory bargain basement price dwight david eisenhower
# Tokenized Text: ['victor', 'y', 'bar', 'gain', 'base', 'ment', 'price', 'd', 'w', 'ight', 'david', 'e', 'is', 'en', 'ho', 'wer']
#
# ==================================================
#
# Original Text:   ir icemoon aftershock djicemoon dubstep trapmusic dnb edm dance ice
# Tokenized Text: ['ir', 'icemoon', 'aftershock', 'dj', 'icemoon', 'dub', 'step', 'tra', 'pm', 'us', 'ic', 'dnb', 'edm', 'dance', 'ice']
#
# ==================================================
#
# Original Text:   remember come second charles schulz
# Tokenized Text: ['remember', 'come', 'second', 'char', 'les', 'sch', 'ul', 'z']
#
# ==================================================
#
# Original Text:   aftershock delo m speak scuf xb people end get ps
# Tokenized Text: ['aftershock', 'de', 'lo', 'm', 'speak', 'sc', 'u', 'f', 'x', 'b', 'people', 'end', 'get', 'ps']
#
# ==================================================
#
# Original Text:   hard conflict glorious triumph thomas paine
# Tokenized Text: ['hard', 'con', 'flict', 'g', 'lor', 'ious', 'tri', 'um', 'ph', 'thom', 'as', 'pa', 'ine']
#
# ==================================================
#
# Original Text:   growingupspoile go clay pigeon shoot cry aftershock
# Tokenized Text: ['grow', 'ing', 'up', 'spo', 'ile', 'go', 'cl', 'ay', 'pi', 'ge', 'on', 'shoot', 'cry', 'aftershock']
#
# ==================================================
#
# Original Text: guess actually want free aftershock tc
# Tokenized Text: ['guess', 'actually', 'want', 'free', 'aftershock', 't', 'c']
#
# ==================================================
#
# Original Text: aftershock terrifying good roller coaster ve disclaimer ve
# Tokenized Text: ['aftershock', 'ter', 'ri', 'fy', 'ing', 'good', 'ro', 'ller', 'co', 'aster', 've', 'dis', 'claim', 'er', 've']
#
# ==================================================
#
# Original Text: aftershock
# Tokenized Text: ['aftershock']
#
# ==================================================
#
# Original Text:   ir icemoon aftershock djicemoon dubstep trapmusic dnb edm dance ice
# Tokenized Text: ['ir', 'icemoon', 'aftershock', 'dj', 'icemoon', 'dub', 'step', 'tra', 'pm', 'us', 'ic', 'dnb', 'edm', 'dance', 'ice']
#
# ==================================================
#
# Original Text:   ir icemoon aftershock djicemoon dubstep trapmusic dnb edm dance ice
# Tokenized Text: ['ir', 'icemoon', 'aftershock', 'dj', 'icemoon', 'dub', 'step', 'tra', 'pm', 'us', 'ic', 'dnb', 'edm', 'dance', 'ice']
#
# ==================================================
#
# Original Text:   ir icemoon aftershock djicemoon dubstep trapmusic dnb edm dance ice
# Tokenized Text: ['ir', 'icemoon', 'aftershock', 'dj', 'icemoon', 'dub', 'step', 'tra', 'pm', 'us', 'ic', 'dnb', 'edm', 'dance', 'ice']
#
# ==================================================
#
# Original Text:   kjforday m see issue aftershock
# Tokenized Text: ['k', 'j', 'for', 'day', 'm', 'see', 'issue', 'aftershock']
#
# ==================================================
#
# Original Text:   ir icemoon aftershock djicemoon dubstep trapmusic dnb edm dance ice
# Tokenized Text: ['ir', 'icemoon', 'aftershock', 'dj', 'icemoon', 'dub', 'step', 'tra', 'pm', 'us', 'ic', 'dnb', 'edm', 'dance', 'ice']
#
# ==================================================
#
# Original Text:   ir icemoon aftershock djicemoon dubstep trapmusic dnb edm dance ice
# Tokenized Text: ['ir', 'icemoon', 'aftershock', 'dj', 'icemoon', 'dub', 'step', 'tra', 'pm', 'us', 'ic', 'dnb', 'edm', 'dance', 'ice']
#
# ==================================================
#
# Original Text:   wisdomwe bonus minute daily habit improve life lifehack
# Tokenized Text: ['wis', 'dom', 'we', 'bon', 'us', 'minute', 'daily', 'h', 'ab', 'it', 'im', 'pro', 've', 'life', 'life', 'h', 'ack']
#
# ==================================================
#
# Original Text: aftershock protect profit global financial meltdown david wiedemer
# Tokenized Text: ['aftershock', 'protect', 'pro', 'fit', 'global', 'financial', 'meltdown', 'david', 'w', 'ie', 'de', 'mer']
#
# ==================================================
#
# Original Text: moment scary roller coaster guy scream bloody murder silverwood aftershock
# Tokenized Text: ['moment', 'scary', 'ro', 'ller', 'co', 'aster', 'guy', 'scream', 'bloody', 'murder', 'silver', 'wood', 'aftershock']
#
# ==================================================
#
# Original Text: aftershock streaming youtube
# Tokenized Text: ['aftershock', 'stream', 'ing', 'youtube']
#
# ==================================================
#
# Original Text:   gt gt aftershock protect profit global financial book esquireattire
# Tokenized Text: ['gt', 'gt', 'aftershock', 'protect', 'pro', 'fit', 'global', 'financial', 'book', 'es', 'quire', 'at', 'ti', 're']
#
# ==================================================
#
# Original Text: face difficulty wrong right joel osteen
# Tokenized Text: ['face', 'di', 'ff', 'ic', 'ul', 'ty', 'wrong', 'right', 'jo', 'el', 'o', 'ste', 'en']
#
# ==================================================
#
# Original Text:   thing stand dream try belief actually possible joel brown
# Tokenized Text: ['thing', 'stand', 'dream', 'try', 'belie', 'f', 'actually', 'possible', 'jo', 'el', 'brown']
#
# ==================================================
#
# Original Text: praise god ministry tell like wdyouth biblestudy
# Tokenized Text: ['pra', 'ise', 'god', 'minist', 'ry', 'tell', 'like', 'wd', 'youth', 'bi', 'ble', 'stud', 'y']
#
# ==================================================
#
# Original Text:   remember go die good way know avoid trap think lose steve job
# Tokenized Text: ['remember', 'go', 'die', 'good', 'way', 'know', 'avoid', 'trap', 'think', 'lose', 'steve', 'job']
#
# ==================================================
#
# Original Text: try orange aftershock today life
# Tokenized Text: ['try', 'or', 'ange', 'aftershock', 'today', 'life']
#
# ==================================================
#
# Original Text:   onfireander love bb
# Tokenized Text: ['on', 'fire', 'an', 'der', 'love', 'bb']
#
# ==================================================
#
# Original Text: aftershock
# Tokenized Text: ['aftershock']
#
# ==================================================
#
# Original Text: aftershock school kick great want thank make possible great night
# Tokenized Text: ['aftershock', 'school', 'kick', 'great', 'want', 'thank', 'make', 'possible', 'great', 'night']
#
# ==================================================
#
# Original Text: people interrupt george bernard shaw
# Tokenized Text: ['people', 'inter', 'ru', 'pt', 'george', 'ber', 'n', 'ard', 'sh', 'aw']
#
# ==================================================
#
# Original Text:   man get oyster second man get shell andrew carnegie
# Tokenized Text: ['man', 'get', 'o', 'y', 'ster', 'second', 'man', 'get', 'sh', 'ell', 'and', 're', 'w', 'car', 'neg', 'ie']
#
# ==================================================
#
# Original Text: need p tonight play hybrid slayer ps eu hmu cod sandscrim empirikgaming codawscrim tp kotc tpfa aftershock org
# Tokenized Text: ['need', 'p', 'tonight', 'play', 'hy', 'b', 'rid', 'sl', 'ay', 'er', 'ps', 'eu', 'h', 'mu', 'co', 'd', 'sand', 'scri', 'm', 'em', 'pi', 'ri', 'k', 'gam', 'ing', 'co', 'da', 'w', 'scri', 'm', 't', 'p', 'k', 'ot', 'c', 't', 'p', 'fa', 'aftershock', 'org']
#
# ==================================================
#
# Original Text: expert france begin examine airplane debris find reunion island french air accident expert news
# Tokenized Text: ['expert', 'france', 'begin', 'examine', 'airplane', 'debris', 'find', 'reunion', 'island', 'french', 'air', 'accident', 'expert', 'news']
#
# ==================================================
#
# Original Text: strict liability context airplane accident pilot error common component aviation cr
# Tokenized Text: ['st', 'rict', 'li', 'ability', 'cont', 'ext', 'airplane', 'accident', 'pilot', 'er', 'ror', 'common', 'comp', 'on', 'ent', 'a', 'vi', 'ation', 'cr']
#
# ==================================================
#
# Original Text:   crobscarla lifetime odd die airplane accident
# Tokenized Text: ['cro', 'b', 'sc', 'ar', 'la', 'life', 'time', 'odd', 'die', 'airplane', 'accident']
#
# ==================================================
#
# Original Text: expert france begin examine airplane debris find reunion island french air accident expert wedn
# Tokenized Text: ['expert', 'france', 'begin', 'examine', 'airplane', 'debris', 'find', 'reunion', 'island', 'french', 'air', 'accident', 'expert', 'we', 'dn']
#
# ==================================================
#
# Original Text:   alexalltimelow awwww airplane accident go to die cutie good job
# Tokenized Text: ['alex', 'all', 'time', 'low', 'a', 'ww', 'ww', 'airplane', 'accident', 'go', 'to', 'die', 'cut', 'ie', 'good', 'job']
#
# ==================================================
#
# Original Text: family member osama bin laden die airplane accident ironic mhmmm gov shit suspect
# Tokenized Text: ['family', 'member', 'os', 'ama', 'bin', 'laden', 'die', 'airplane', 'accident', 'ir', 'on', 'ic', 'mh', 'mm', 'm', 'gov', 'shit', 'suspect']
#
# ==================================================
#
# Original Text: man go airplane engine accident youtube
# Tokenized Text: ['man', 'go', 'airplane', 'engine', 'accident', 'youtube']
#
# ==================================================
#
# Original Text: horrible accident man die wing airplane
# Tokenized Text: ['horrible', 'accident', 'man', 'die', 'wing', 'airplane']
#
# ==================================================
#
# Original Text: cessna airplane accident ocampo coahuila mexico july kill man include state coahuila government official
# Tokenized Text: ['cess', 'na', 'airplane', 'accident', 'oc', 'am', 'po', 'co', 'ah', 'u', 'il', 'a', 'mex', 'ico', 'ju', 'ly', 'kill', 'man', 'include', 'state', 'co', 'ah', 'u', 'il', 'a', 'government', 'official']
#
# ==================================================
#
# Original Text:   horrible accident man die wing airplane watchthevideo
# Tokenized Text: ['horrible', 'accident', 'man', 'die', 'wing', 'airplane', 'watch', 'the', 'video']
#
# ==================================================
#
# Original Text: expert france begin examine airplane debris find reunion island french air accident expert wednesday
# Tokenized Text: ['expert', 'france', 'begin', 'examine', 'airplane', 'debris', 'find', 'reunion', 'island', 'french', 'air', 'accident', 'expert', 'wednesday']
#
# ==================================================
#
# Original Text: expert france begin examine airplane debris find reunion island french air accident expert wednesday begin examine
# Tokenized Text: ['expert', 'france', 'begin', 'examine', 'airplane', 'debris', 'find', 'reunion', 'island', 'french', 'air', 'accident', 'expert', 'wednesday', 'begin', 'examine']
#
# ==================================================
#
# Original Text:   kca votejkt d mbataweel rip binladen family member kill airplane accident
# Tokenized Text: ['k', 'ca', 'vote', 'jk', 't', 'd', 'm', 'bat', 'awe', 'el', 'rip', 'bin', 'laden', 'family', 'member', 'kill', 'airplane', 'accident']
#
# ==================================================
#
# Original Text: send coworker nude accident thank god airplane mode
# Tokenized Text: ['send', 'co', 'worker', 'nu', 'de', 'accident', 'thank', 'god', 'airplane', 'mode']
#
# ==================================================
#
# Original Text:   mickinyman theatlantic kill airplane accident night car wreck politic good
# Tokenized Text: ['m', 'ick', 'in', 'y', 'man', 'the', 'atl', 'ant', 'ic', 'kill', 'airplane', 'accident', 'night', 'car', 'wreck', 'politic', 'good']
#
# ==================================================
#
# Original Text: expert france begin examine airplane debris find reunion island french air accident expert mlb
# Tokenized Text: ['expert', 'france', 'begin', 'examine', 'airplane', 'debris', 'find', 'reunion', 'island', 'french', 'air', 'accident', 'expert', 'ml', 'b']
#
# ==================================================
#
# Original Text: unbelievably insane man airport airplane aircraft aeroplane runway accident freaky
# Tokenized Text: ['un', 'be', 'li', 'ev', 'ab', 'ly', 'ins', 'ane', 'man', 'airport', 'airplane', 'aircraft', 'a', 'ero', 'plane', 'run', 'way', 'accident', 'freak', 'y']
#
# ==================================================
#
# Original Text: horrible accident man die wing airplane
# Tokenized Text: ['horrible', 'accident', 'man', 'die', 'wing', 'airplane']
#
# ==================================================
#
# Original Text: horrible accident man die wing airplane
# Tokenized Text: ['horrible', 'accident', 'man', 'die', 'wing', 'airplane']
#
# ==================================================
#
# Original Text: usama bin ladin family dead airplane crash naturally accident
# Tokenized Text: ['us', 'ama', 'bin', 'lad', 'in', 'family', 'dead', 'airplane', 'crash', 'nat', 'ur', 'ally', 'accident']
#
# ==================================================
#
# Original Text: pilot die plane crash car festival youtube crash aircraft airplane pilot death accident carfest
# Tokenized Text: ['pilot', 'die', 'plane', 'crash', 'car', 'fest', 'i', 'val', 'youtube', 'crash', 'aircraft', 'airplane', 'pilot', 'death', 'accident', 'car', 'fest']
#
# ==================================================
#
# Original Text: strict liability context airplane accident
# Tokenized Text: ['st', 'rict', 'li', 'ability', 'cont', 'ext', 'airplane', 'accident']
#
# ==================================================
#
# Original Text: dtn brazil expert france begin examine airplane debris find reunion island french air accident exp
# Tokenized Text: ['dt', 'n', 'braz', 'il', 'expert', 'france', 'begin', 'examine', 'airplane', 'debris', 'find', 'reunion', 'island', 'french', 'air', 'accident', 'exp']
#
# ==================================================
#
# Original Text: expert france begin examine airplane debris find reunion island french air accident expert wedn
# Tokenized Text: ['expert', 'france', 'begin', 'examine', 'airplane', 'debris', 'find', 'reunion', 'island', 'french', 'air', 'accident', 'expert', 'we', 'dn']
#
# ==================================================
#
# Original Text: horrible accident man die wing airplane wtf believe eye
# Tokenized Text: ['horrible', 'accident', 'man', 'die', 'wing', 'airplane', 'wtf', 'believe', 'eye']
#
# ==================================================
#
# Original Text:   nicole fletcher victim crash airplane time ago accident leave little bit trauma
# Tokenized Text: ['n', 'ic', 'ole', 'f', 'let', 'cher', 'victim', 'crash', 'airplane', 'time', 'ago', 'accident', 'leave', 'little', 'bit', 'trauma']
#
# ==================================================
#
# Original Text: omg horrible accident man die wing airplane
# Tokenized Text: ['omg', 'horrible', 'accident', 'man', 'die', 'wing', 'airplane']
#
# ==================================================
#
# Original Text:   omg don believe rip bro airplane accident jetengine turbojet boe
# Tokenized Text: ['omg', 'don', 'believe', 'rip', 'bro', 'airplane', 'accident', 'jet', 'engine', 'tur', 'bo', 'jet', 'bo', 'e']
#
# ==================================================
#
# Original Text: expert france begin examine airplane debris find reunion island french air accident expert wednesday begin examine
# Tokenized Text: ['expert', 'france', 'begin', 'examine', 'airplane', 'debris', 'find', 'reunion', 'island', 'french', 'air', 'accident', 'expert', 'wednesday', 'begin', 'examine']
#
# ==================================================
#
# Original Text: airplane accident
# Tokenized Text: ['airplane', 'accident']
#
# ==================================================
#
# Original Text: phone look like car ship airplane accident terrible
# Tokenized Text: ['phone', 'look', 'like', 'car', 'ship', 'airplane', 'accident', 'ter', 'rible']
#
# ==================================================
#
# Original Text: statistically m risk getting kill cop die airplane accident
# Tokenized Text: ['stat', 'istic', 'ally', 'm', 'risk', 'getting', 'kill', 'cop', 'die', 'airplane', 'accident']
#
# ==================================================
#
# Original Text: airplane crash house colombia people die accident
# Tokenized Text: ['airplane', 'crash', 'house', 'colo', 'mb', 'ia', 'people', 'die', 'accident']
#
# ==================================================
#
# Original Text: shooting airplane accident
# Tokenized Text: ['shooting', 'airplane', 'accident']
#
# ==================================================
#
# Original Text: drone cause airplane accident pilot worry use drone esp close vicinity airport
# Tokenized Text: ['drone', 'cause', 'airplane', 'accident', 'pilot', 'worry', 'use', 'drone', 'e', 'sp', 'close', 'vic', 'in', 'ity', 'airport']
#
# ==================================================
#
# Original Text: early wake sister beg come amp ride ambulance hospital rodkiai
# Tokenized Text: ['early', 'wake', 'sister', 'be', 'g', 'come', 'amp', 'ri', 'de', 'ambulance', 'hospital', 'ro', 'd', 'k', 'ia', 'i']
#
# ==================================================
#
# Original Text:   fear kill pakistani air ambulance helicopter crash
# Tokenized Text: ['fear', 'kill', 'pakistani', 'air', 'ambulance', 'helicopter', 'crash']
#
# ==================================================
#
# Original Text: air ambulance scene crash car lorry emsne
# Tokenized Text: ['air', 'ambulance', 'scene', 'crash', 'car', 'lor', 'ry', 'ems', 'ne']
#
# ==================================================
#
# Original Text: fear kill pakistani air ambulance helicopter crash reuters yugvani
# Tokenized Text: ['fear', 'kill', 'pakistani', 'air', 'ambulance', 'helicopter', 'crash', 'reuters', 'y', 'ug', 'van', 'i']
#
# ==================================================
#
# Original Text: lead emergency service boss welcome new ambulance charity
# Tokenized Text: ['lead', 'emergency', 'service', 'bo', 'ss', 'welcome', 'new', 'ambulance', 'char', 'ity']
#
# ==================================================
#
# Original Text: travel aberystwyth shrewsbury right incident service halt outside shrew ambulance scene
# Tokenized Text: ['travel', 'ab', 'ery', 'st', 'wy', 'th', 'sh', 're', 'ws', 'b', 'ury', 'right', 'incident', 'service', 'hal', 't', 'outside', 'sh', 're', 'w', 'ambulance', 'scene']
#
# ==================================================
#
# Original Text: fear kill pakistani air ambulance helicopter crash
# Tokenized Text: ['fear', 'kill', 'pakistani', 'air', 'ambulance', 'helicopter', 'crash']
#
# ==================================================
#
# Original Text: ambulance sprinter automatic frontline vehicle choice lez compliant ebay
# Tokenized Text: ['ambulance', 'sp', 'r', 'inter', 'autom', 'atic', 'front', 'line', 'vehicle', 'choice', 'le', 'z', 'comp', 'li', 'ant', 'ebay']
#
# ==================================================
#
# Original Text: new nanotech device able target destroy blood clot
# Tokenized Text: ['new', 'nan', 'ote', 'ch', 'dev', 'ice', 'able', 'target', 'destroy', 'blood', 'c', 'lot']
#
# ==================================================
#
# Original Text:   skyhawkmm traplord fredosantana lilreese hella crazy fight ambulance couple mosh pit
# Tokenized Text: ['sky', 'ha', 'w', 'km', 'm', 'tra', 'pl', 'ord', 'f', 'red', 'os', 'ant', 'ana', 'lil', 'ree', 'se', 'hel', 'la', 'crazy', 'fight', 'ambulance', 'couple', 'mo', 'sh', 'pit']
#
# ==================================================
#
# Original Text: run ambulance lucky justsaye randomthought
# Tokenized Text: ['run', 'ambulance', 'lucky', 'just', 'say', 'e', 'r', 'and', 'om', 'thought']
#
# ==================================================
#
# Original Text:   news fear kill pakistani air ambulance helicopter crash til dna
# Tokenized Text: ['news', 'fear', 'kill', 'pakistani', 'air', 'ambulance', 'helicopter', 'crash', 't', 'il', 'd', 'na']
#
# ==================================================
#
# Original Text:   fear kill pakistani air ambulance helicopter crash
# Tokenized Text: ['fear', 'kill', 'pakistani', 'air', 'ambulance', 'helicopter', 'crash']
#
# ==================================================
#
# Original Text:   tanslash wait ambulance
# Tokenized Text: ['t', 'ans', 'la', 'sh', 'wait', 'ambulance']
#
# ==================================================
#
# Original Text:   fouseytube ok need ambulance hahahah good
# Tokenized Text: ['fo', 'use', 'y', 'tube', 'ok', 'need', 'ambulance', 'haha', 'ha', 'h', 'good']
#
# ==================================================
#
# Original Text: ambulance sprinter automatic frontline vehicle choice lez compliant ebay
# Tokenized Text: ['ambulance', 'sp', 'r', 'inter', 'autom', 'atic', 'front', 'line', 'vehicle', 'choice', 'le', 'z', 'comp', 'li', 'ant', 'ebay']
#
# ==================================================
#
# Original Text: pakistan air ambulance helicopter crash kill
# Tokenized Text: ['pakistan', 'air', 'ambulance', 'helicopter', 'crash', 'kill']
#
# ==================================================
#
# Original Text:   thenissonian rejectdcartoon nissan ok need medical assistance ambulance need
# Tokenized Text: ['th', 'en', 'is', 'son', 'ian', 're', 'ject', 'd', 'car', 'to', 'on', 'n', 'is', 'san', 'ok', 'need', 'med', 'ical', 'ass', 'ist', 'ance', 'ambulance', 'need']
#
# ==================================================
#
# Original Text: ems ny emts petition hour minimum wage ems paramedics ambulance
# Tokenized Text: ['ems', 'ny', 'em', 'ts', 'petition', 'hour', 'min', 'im', 'um', 'w', 'age', 'ems', 'par', 'am', 'ed', 'ics', 'ambulance']
#
# ==================================================
#
# Original Text:   fear kill pakistani air ambulance helicopter crash
# Tokenized Text: ['fear', 'kill', 'pakistani', 'air', 'ambulance', 'helicopter', 'crash']
#
# ==================================================
#
# Original Text: fear kill pakistani air ambulance helicopter crash
# Tokenized Text: ['fear', 'kill', 'pakistani', 'air', 'ambulance', 'helicopter', 'crash']
#
# ==================================================
#
# Original Text: ambulance sprinter automatic frontline vehicle choice lez compliant ebay
# Tokenized Text: ['ambulance', 'sp', 'r', 'inter', 'autom', 'atic', 'front', 'line', 'vehicle', 'choice', 'le', 'z', 'comp', 'li', 'ant', 'ebay']
#
# ==================================================
#
# Original Text: ambulance sprinter automatic frontline vehicle choice lez compliant ebay
# Tokenized Text: ['ambulance', 'sp', 'r', 'inter', 'autom', 'atic', 'front', 'line', 'vehicle', 'choice', 'le', 'z', 'comp', 'li', 'ant', 'ebay']
#
# ==================================================
#
# Original Text:   kiwi karyn check parking lot say year ambulance st johns
# Tokenized Text: ['ki', 'wi', 'k', 'ary', 'n', 'check', 'par', 'king', 'lot', 'say', 'year', 'ambulance', 'st', 'john', 's']
#
# ==================================================
#
# Original Text: don know way ambulance come lt lt
# Tokenized Text: ['don', 'know', 'way', 'ambulance', 'come', 'lt', 'lt']
#
# ==================================================
#
# Original Text:   reuters fear kill pakistani air ambulance helicopter crash
# Tokenized Text: ['reuters', 'fear', 'kill', 'pakistani', 'air', 'ambulance', 'helicopter', 'crash']
#
# ==================================================
#
# Original Text:   fear kill pakistani air ambulance helicopter crash
# Tokenized Text: ['fear', 'kill', 'pakistani', 'air', 'ambulance', 'helicopter', 'crash']
#
# ==================================================
#
# Original Text: ambulance right outside work
# Tokenized Text: ['ambulance', 'right', 'outside', 'work']
#
# ==================================================
#
# Original Text:   leoblakecarter dog think ambulance
# Tokenized Text: ['le', 'ob', 'lake', 'car', 'ter', 'dog', 'think', 'ambulance']
#
# ==================================================
#
# Original Text: happen hatzolah ems ambulance respond dual siren
# Tokenized Text: ['happen', 'hat', 'zo', 'la', 'h', 'ems', 'ambulance', 'respond', 'dual', 'siren']
#
# ==================================================
#
# Original Text:   fear kill pakistani air ambulance helicopter crash
# Tokenized Text: ['fear', 'kill', 'pakistani', 'air', 'ambulance', 'helicopter', 'crash']
#
# ==================================================
#
# Original Text:   fear kill pakistani air ambulance helicopter crash
# Tokenized Text: ['fear', 'kill', 'pakistani', 'air', 'ambulance', 'helicopter', 'crash']
#
# ==================================================
#
# Original Text: fear kill pakistani air ambulance helicopter crash worldnews
# Tokenized Text: ['fear', 'kill', 'pakistani', 'air', 'ambulance', 'helicopter', 'crash', 'worldnews']
#
# ==================================================
#
# Original Text: fear kill pakistani air ambulance helicopter crash worldnews
# Tokenized Text: ['fear', 'kill', 'pakistani', 'air', 'ambulance', 'helicopter', 'crash', 'worldnews']
#
# ==================================================
#
# Original Text: police ambulance number lesotho body know
# Tokenized Text: ['police', 'ambulance', 'number', 'le', 'so', 'tho', 'body', 'know']
#
# ==================================================
#
# Original Text:   medic aace org surprised standardised clinical practice nhs ambulance trust
# Tokenized Text: ['med', 'ic', 'a', 'ace', 'org', 'surprise', 'd', 'stand', 'ar', 'dise', 'd', 'cl', 'in', 'ical', 'practice', 'nh', 's', 'ambulance', 'trust']
#
# ==================================================
#
# Original Text:   fear kill pakistani air ambulance helicopter crash
# Tokenized Text: ['fear', 'kill', 'pakistani', 'air', 'ambulance', 'helicopter', 'crash']
#
# ==================================================
#
# Original Text: people try walk ambulance pass hate
# Tokenized Text: ['people', 'try', 'walk', 'ambulance', 'pass', 'hate']
#
# ==================================================
#
# Original Text: episode trunk annihilate freiza clean shit show nigga mercy
# Tokenized Text: ['episode', 'tr', 'unk', 'annihilate', 'fre', 'iz', 'a', 'clean', 'shit', 'show', 'nigga', 'mer', 'cy']
#
# ...
#
# ==================================================
#
# Original Text: wreckage conclusively confirm mh malaysia pm investigator family
# Tokenized Text: ['wreckage', 'conclusively', 'confirm', 'mh', 'malaysia', 'pm', 'investigator', 'family']
#
# ==================================================
#
# Original Text: wreckage conclusively confirm mh malaysia pm investigator family
# Tokenized Text: ['wreckage', 'conclusively', 'confirm', 'mh', 'malaysia', 'pm', 'investigator', 'family']
#
# ==================================================
#
# Original Text: wreckage conclusively confirm miss flight mh yahoonewsdigest
# Tokenized Text: ['wreckage', 'conclusively', 'confirm', 'miss', 'flight', 'mh', 'yaho', 'one', 'ws', 'di', 'ge', 'st']
#
# ==================================================
#
# Original Text: wreckage conclusively confirm mh malaysia pm investigator family
# Tokenized Text: ['wreckage', 'conclusively', 'confirm', 'mh', 'malaysia', 'pm', 'investigator', 'family']
#
# ==================================================
#
# Original Text: wreck hour youtube julian lage grantgordy amp rossmartin practice time
# Tokenized Text: ['wreck', 'hour', 'youtube', 'ju', 'li', 'an', 'la', 'ge', 'gr', 'ant', 'g', 'or', 'dy', 'amp', 'ross', 'mart', 'in', 'practice', 'time']
#
# ==================================================
#
# Original Text: late night mcdonalds friend hilarious car wreck half steak pastie industrial estate
# Tokenized Text: ['late', 'night', 'mc', 'donald', 's', 'friend', 'hil', 'ar', 'ious', 'car', 'wreck', 'half', 'ste', 'ak', 'past', 'ie', 'indust', 'ri', 'al', 'est', 'ate']
#
# ==================================================
#
# Original Text: good luck school soon sleep schedule wreck repair
# Tokenized Text: ['good', 'luck', 'school', 'soon', 'sleep', 'sch', 'edu', 'le', 'wreck', 'repair']
#
# ==================================================
#
# Original Text: wonder time wreck try stare drive fast furious
# Tokenized Text: ['wonder', 'time', 'wreck', 'try', 'st', 'are', 'drive', 'fast', 'fur', 'ious']
#
# ==================================================
#
# Original Text: wreck car cost apiece purchase making film
# Tokenized Text: ['wreck', 'car', 'cost', 'ap', 'ie', 'ce', 'pur', 'chase', 'ma', 'king', 'film']
#
# ==================================================
#
# Original Text: cramer iger word wreck disney stock cnbc
# Tokenized Text: ['cr', 'amer', 'ig', 'er', 'word', 'wreck', 'disney', 'stock', 'c', 'nbc']
#
# ==================================================
#
# Original Text: poor liv get phone wreck day oliviaapalmerr thatswhatfriendsarefor
# Tokenized Text: ['poor', 'li', 'v', 'get', 'phone', 'wreck', 'day', 'o', 'li', 'vi', 'a', 'ap', 'al', 'mer', 'r', 'that', 's', 'wh', 'at', 'friend', 'sa', 're', 'for']
#
# ==================================================
#
# Original Text: freeway africa til wreck audi
# Tokenized Text: ['free', 'way', 'africa', 't', 'il', 'wreck', 'au', 'di']
#
# ==================================================
#
# Original Text: israel wreck home want land
# Tokenized Text: ['israel', 'wreck', 'home', 'want', 'land']
#
# ==================================================
#
# Original Text:   news cramer iger word wreck disney stock til cnbc
# Tokenized Text: ['news', 'cr', 'amer', 'ig', 'er', 'word', 'wreck', 'disney', 'stock', 't', 'il', 'c', 'nbc']
#
# ==================================================
#
# Original Text: james kunstler bad architecture wreck city residualincome mlm
# Tokenized Text: ['j', 'ame', 's', 'k', 'un', 'st', 'ler', 'bad', 'arch', 'ite', 'ct', 'ure', 'wreck', 'city', 're', 'si', 'dual', 'in', 'come', 'ml', 'm']
#
# ==================================================
#
# Original Text:   iger word wreck disney stock
# Tokenized Text: ['ig', 'er', 'word', 'wreck', 'disney', 'stock']
#
# ==================================================
#
# Original Text: twitter update pretty wreck app
# Tokenized Text: ['twitter', 'update', 'pretty', 'wreck', 'app']
#
# ==================================================
#
# Original Text: wreck feel low life okay god get
# Tokenized Text: ['wreck', 'feel', 'low', 'life', 'okay', 'god', 'get']
#
# ==================================================
#
# Original Text: coleslaw wreck
# Tokenized Text: ['co', 'le', 'sla', 'w', 'wreck']
#
# ==================================================
#
# Original Text:   exotic car wreck train accident
# Tokenized Text: ['ex', 'ot', 'ic', 'car', 'wreck', 'train', 'accident']
#
# ==================================================
#
# Original Text: twins pitcher ego wreck
# Tokenized Text: ['tw', 'ins', 'pit', 'cher', 'e', 'go', 'wreck']
#
# ==================================================
#
# Original Text:   tune wgg lol get wreck
# Tokenized Text: ['tune', 'w', 'gg', 'lol', 'get', 'wreck']
#
# ==================================================
#
# Original Text: wreck world
# Tokenized Text: ['wreck', 'world']
#
# ==================================================
#
# Original Text: wreck stomach help
# Tokenized Text: ['wreck', 'st', 'om', 'ach', 'help']
#
# ==================================================
#
# Original Text:   ohhmyjoshh stevenrulle go to think get shit wreck day school
# Tokenized Text: ['oh', 'h', 'my', 'jo', 'sh', 'h', 'st', 'even', 'ru', 'l', 'le', 'go', 'to', 'think', 'get', 'shit', 'wreck', 'day', 'school']
#
# ==================================================
#
# Original Text: wreck tired go to asleep
# Tokenized Text: ['wreck', 'tired', 'go', 'to', 'as', 'leep']
#
# ==================================================
#
# Original Text:   cramer iger word wreck disney stock
# Tokenized Text: ['cr', 'amer', 'ig', 'er', 'word', 'wreck', 'disney', 'stock']
#
# ==================================================
#
# Original Text: wreck emotion
# Tokenized Text: ['wreck', 'emotion']
#
# ==================================================
#
# Original Text: riddler good early exit primary presidential wannabe certain chance get wreck rich guy
# Tokenized Text: ['rid', 'd', 'ler', 'good', 'early', 'exit', 'pri', 'mary', 'president', 'ial', 'wanna', 'be', 'certain', 'chance', 'get', 'wreck', 'rich', 'guy']
#
# ==================================================
#
# Original Text:   marynmck adorable hope win wreck notice
# Tokenized Text: ['mary', 'n', 'm', 'ck', 'ad', 'or', 'able', 'hope', 'win', 'wreck', 'notice']
#
# ==================================================
#
# Original Text: cramer iger word wreck disney stock cnbc topnews
# Tokenized Text: ['cr', 'amer', 'ig', 'er', 'word', 'wreck', 'disney', 'stock', 'c', 'nbc', 't', 'op', 'news']
#
# ==================================================
#
# Original Text:   caitsrobert night wee barra absolutely wreck
# Tokenized Text: ['ca', 'its', 'robert', 'night', 'we', 'e', 'bar', 'ra', 'absolutely', 'wreck']
#
# ==================================================
#
# Original Text:   kirafrog mount wario wreck
# Tokenized Text: ['ki', 'ra', 'fro', 'g', 'mount', 'war', 'io', 'wreck']
#
# ==================================================
#
# Original Text: awesome time gettin wreck bowling night
# Tokenized Text: ['awesome', 'time', 'get', 'tin', 'wreck', 'bow', 'ling', 'night']
#
# ==================================================
#
# Original Text: cramer word wreck dis stock
# Tokenized Text: ['cr', 'amer', 'word', 'wreck', 'dis', 'stock']
#
# ==================================================
#
# Original Text: bright wreck
# Tokenized Text: ['b', 'right', 'wreck']
#
# ==================================================
#
# Original Text: wreck
# Tokenized Text: ['wreck']
#
# ==================================================
#
# Original Text:   widda go relax think wife wreck cake goner mind lol whoops
# Tokenized Text: ['w', 'id', 'da', 'go', 're', 'la', 'x', 'think', 'wife', 'wreck', 'cake', 'gon', 'er', 'mind', 'lol', 'w', 'ho', 'op', 's']
#
# ==================================================
#
# Original Text:   jt ruff cameronhacker wreck
# Tokenized Text: ['j', 't', 'ru', 'ff', 'camer', 'on', 'h', 'ack', 'er', 'wreck']
#
# ==================================================
#
# Original Text: day work ve pretty wreck hahaha shoutout family
# Tokenized Text: ['day', 'work', 've', 'pretty', 'wreck', 'haha', 'ha', 'sh', 'out', 'out', 'family']
#
# ==================================================
#
# Original Text:   fx forex trading cramer iger word wreck disney stock
# Tokenized Text: ['f', 'x', 'fore', 'x', 'tra', 'ding', 'cr', 'amer', 'ig', 'er', 'word', 'wreck', 'disney', 'stock']
#
# ==================================================
#
# Original Text:   engineshe great atmosphere british lion gig tonight hearing wreck
# Tokenized Text: ['engine', 'she', 'great', 'at', 'mo', 'sp', 'her', 'e', 'british', 'lion', 'g', 'ig', 'tonight', 'hear', 'ing', 'wreck']
#
# ==================================================
#
# Original Text: cramer iger word wreck disney stock cnbc
# Tokenized Text: ['cr', 'amer', 'ig', 'er', 'word', 'wreck', 'disney', 'stock', 'c', 'nbc']
#
# ==================================================
#
# Original Text: pic yr old pkk suicide bomber detonate bomb turkey army trench release
# Tokenized Text: ['pic', 'yr', 'old', 'pkk', 'suicide', 'bomber', 'detonate', 'bomb', 'turkey', 'army', 'trench', 'release']
#
# ==================================================
#
# Original Text: box ready explode explode kitten finally arrive gameofkitten explodingkitten
# Tokenized Text: ['box', 'ready', 'explode', 'explode', 'kit', 'ten', 'finally', 'arrive', 'game', 'of', 'kit', 'ten', 'explo', 'ding', 'kit', 'ten']
#
# ==================================================
#
# Original Text: calgary police flood road closure calgary
# Tokenized Text: ['calgary', 'police', 'flood', 'road', 'clo', 'sure', 'calgary']
#
# ==================================================
#
# Original Text:   sismo detectado jap seismic intensity iwate miyagi jst
# Tokenized Text: ['sismo', 'de', 'te', 'ct', 'ado', 'jap', 'seismic', 'inten', 'sity', 'i', 'w', 'ate', 'mi', 'y', 'ag', 'i', 'j', 'st']
#
# ==================================================
#
# Original Text: siren
# Tokenized Text: ['siren']
#
# ==================================================
#
# Original Text: break isis claim responsibility mosque attack saudi arabia kill
# Tokenized Text: ['break', 'isis', 'claim', 'respon', 'si', 'bi', 'li', 'ty', 'mosque', 'attack', 'saudi', 'arab', 'ia', 'kill']
#
# ==================================================
#
# Original Text: omg earthquake
# Tokenized Text: ['omg', 'earthquake']
#
# ==================================================
#
# Original Text: severe weather bulletin typhoon hannaph soudelor tropical cyclone warning issue pm
# Tokenized Text: ['severe', 'weather', 'bullet', 'in', 'typhoon', 'han', 'nap', 'h', 'soudelor', 'tro', 'pical', 'cyclone', 'warning', 'issue', 'pm']
#
# ==================================================
#
# Original Text: heat wave warn aa ayyo dei plan visit friend year
# Tokenized Text: ['heat', 'wave', 'warn', 'aa', 'ay', 'yo', 'de', 'i', 'plan', 'visit', 'friend', 'year']
#
# ==================================================
#
# Original Text: group suicide bomber detonate explosive pack vest mosque inside saudi special force headquarter kill people
# Tokenized Text: ['group', 'suicide', 'bomber', 'detonate', 'explo', 'sive', 'pack', 'vest', 'mosque', 'inside', 'saudi', 'special', 'force', 'head', 'quar', 'ter', 'kill', 'people']
#
# ==================================================
#
# Original Text: hear loud bang asleep great
# Tokenized Text: ['hear', 'loud', 'bang', 'as', 'leep', 'great']
#
# ==================================================
#
# Original Text: gas thing explode hear scream street smell gas
# Tokenized Text: ['gas', 'thing', 'explode', 'hear', 'scream', 'street', 'sme', 'll', 'gas']
#
# ==================================================
#
# Original Text: nws flash flood warning continue shelby county pm wednesday tnwx
# Tokenized Text: ['nws', 'flash', 'flood', 'warning', 'continue', 'shel', 'by', 'county', 'pm', 'wednesday', 't', 'n', 'wx']
#
# ==================================================
#
# Original Text: rt livingsafely nws issue severe thunderstorm warning part ar nc ok expect trauma case
# Tokenized Text: ['rt', 'li', 'ving', 'sa', 'f', 'ely', 'nws', 'issue', 'severe', 'thunderstorm', 'warning', 'part', 'ar', 'nc', 'ok', 'expect', 'trauma', 'case']
#
# ==================================================
#
# Original Text:   mh aircraft debris find la reunion miss malaysia airline
# Tokenized Text: ['mh', 'aircraft', 'debris', 'find', 'la', 'reunion', 'miss', 'malaysia', 'airline']
#
# ==================================================
#
# Original Text: father lose control car overtake collide bathandnortheastsomerset
# Tokenized Text: ['father', 'lose', 'control', 'car', 'over', 'take', 'collide', 'bath', 'and', 'nor', 'the', 'ast', 'som', 'er', 'set']
#
# ==================================================
#
# Original Text:   earthquake km ssw anza california iphone user download earthquake app information
# Tokenized Text: ['earthquake', 'km', 'ss', 'w', 'an', 'za', 'california', 'i', 'phone', 'user', 'download', 'earthquake', 'app', 'information']
#
# ==================================================
#
# Original Text: evacuation order lift town roosevelt
# Tokenized Text: ['evacuation', 'order', 'lift', 'town', 'roosevelt']
#
# ==================================================
#
# Original Text:   break la refugio oil spill costlier big project
# Tokenized Text: ['break', 'la', 'refugio', 'oil', 'spill', 'costlier', 'big', 'project']
#
# ==================================================
#
# Original Text: siren go wasn forney tornado warn
# Tokenized Text: ['siren', 'go', 'wasn', 'for', 'ney', 'tornado', 'warn']
#
# ==================================================
#
# Original Text: official quarantine place alabama home possible ebola case develop symptom
# Tokenized Text: ['official', 'quarantine', 'place', 'alabama', 'home', 'possible', 'ebola', 'case', 'de', 've', 'lo', 'p', 'sy', 'mp', 'tom']
#
# ==================================================
#
# Original Text:   worldnews fall powerline link tram update fire crew evacuate passenger tr
# Tokenized Text: ['worldnews', 'fall', 'power', 'line', 'link', 'tr', 'am', 'update', 'fire', 'crew', 'evacuate', 'passenger', 'tr']
#
# ==================================================
#
# Original Text: flip m walmart bomb evacuate stay tuned blow
# Tokenized Text: ['f', 'lip', 'm', 'wal', 'mart', 'bomb', 'evacuate', 'stay', 'tun', 'ed', 'blow']
#
# ==================================================
#
# Original Text: suicide bomber kill saudi security site mosque reuters world google news wall
# Tokenized Text: ['suicide', 'bomber', 'kill', 'saudi', 'security', 'site', 'mosque', 'reuters', 'world', 'go', 'o', 'gle', 'news', 'wall']
#
# ==================================================
#
# Original Text:   stormchase violent record breaking ef el reno oklahoma tornado nearly run
# Tokenized Text: ['storm', 'chase', 'violent', 'record', 'breaking', 'ef', 'el', 're', 'no', 'oklahoma', 'tornado', 'nearly', 'run']
#
# ==================================================
#
# Original Text: giant crane hold bridge collapse nearby home
# Tokenized Text: ['giant', 'crane', 'hold', 'bridge', 'collapse', 'nearby', 'home']
#
# ==================================================
#
# Original Text:   aria ahrary thetawniest control wild fire california northern state troubling
# Tokenized Text: ['ar', 'ia', 'ah', 'r', 'ary', 'the', 'ta', 'w', 'ni', 'est', 'control', 'wild', 'fire', 'california', 'northern', 'state', 'tro', 'u', 'bl', 'ing']
#
# ==================================================
#
# Original Text: utc km volcano hawaii
# Tokenized Text: ['utc', 'km', 'volcano', 'hawaii']
#
# ==================================================
#
# Original Text: police investigate bike collide car little portugal bike rider suffer non life threaten injury
# Tokenized Text: ['police', 'investigate', 'bi', 'ke', 'collide', 'car', 'little', 'port', 'ug', 'al', 'bi', 'ke', 'ri', 'der', 'suffer', 'non', 'life', 'threaten', 'injury']
#
# ==================================================
#
# Original Text: late home raze northern california wildfire abc news
# Tokenized Text: ['late', 'home', 'raze', 'northern', 'california', 'wildfire', 'abc', 'news']
#
# ==================================================

# %%
tweets_train
# Out:
#                                                    text  target  \
# 0     Our Deeds are the Reason of this #earthquake M...       1
# 1                Forest fire near La Ronge Sask. Canada       1
# 2     All residents asked to 'shelter in place' are ...       1
# 3     13,000 people receive #wildfires evacuation or...       1
# 4     Just got sent this photo from Ruby #Alaska as ...       1
# ...                                                 ...     ...
# 7608  Two giant cranes holding a bridge collapse int...       1
# 7609  @aria_ahrary @TheTawniest The out of control w...       1
# 7610  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...       1
# 7611  Police investigating after an e-bike collided ...       1
# 7612  The Latest: More Homes Razed by Northern Calif...       1
#
#                                              clean_text  \
# 0                  deed reason earthquake allah forgive
# 1                 forest fire near la ronge sask canada
# 2     resident ask shelter place notify officer evac...
# 3       people receive wildfire evacuation order cal...
# 4     get send photo ruby alaska smoke wildfire pour...
# ...                                                 ...
# 7608       giant crane hold bridge collapse nearby home
# 7609    aria ahrary thetawniest control wild fire ca...
# 7610                              utc km volcano hawaii
# 7611  police investigate bike collide car little por...
# 7612  late home raze northern california wildfire ab...
#
#                                          tokenized_text
# 0        [de, ed, reason, earthquake, allah, for, give]
# 1     [forest, fire, near, la, ron, ge, s, ask, canada]
# 2     [resident, ask, shel, ter, place, not, ify, of...
# 3     [people, re, ce, ive, wildfire, evacuation, or...
# 4     [get, send, photo, ru, by, alaska, smoke, wild...
# ...                                                 ...
# 7608  [giant, crane, hold, bridge, collapse, nearby,...
# 7609  [ar, ia, ah, r, ary, the, ta, w, ni, est, cont...
# 7610                         [utc, km, volcano, hawaii]
# 7611  [police, investigate, bi, ke, collide, car, li...
# 7612  [late, home, raze, northern, california, wildf...
#
# [7613 rows x 4 columns]

# %%
def get_tfidf_matrix(df, vectorizer):

    # Convert the TF-IDF matrix to a dense NumPy array
    matrix = df.todense()

    # Convert the dense matrix to a DataFrame
    matrix = pd.DataFrame(matrix, columns=vectorizer.get_feature_names_out())

    return matrix


# The sequences being in the formar ['word1', 'word2', 'word3', ...], preprocess it
def string2embedding_idx(text_sequence, model):

    sequence = []
    for token in text_sequence:
        try:
            sequence.append(model.wv.key_to_index[token])
        except:
            pass

    return sequence

# %%
class TweetsDataset(torch.utils.data.Dataset):
    def __init__(self, df, word2vec_model):
        self.df = df
        self.word2vec_model = word2vec_model

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        sequence = self.df.iloc[idx, -1 if self.word2vec_model == 'skipgram' else -2]
        label = self.df.iloc[idx, 1]

        # Convert sequence to a 1D tensor
        sequence_tensor = torch.tensor(sequence, dtype=torch.long)

        # Convert label to a 1D tensor (scalar)
        label_tensor = torch.tensor(label, dtype=torch.float32).unsqueeze(0)

        return sequence_tensor, label_tensor
